# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
df1 = pd.read_excel(r"C:\Users\sbrooks003\OneDrive - defiance.edu\seasons(updated).xlsx",sheet_name='Sheet1')
df1
# Out:
#          Year                Player  Pos   Age   Tm     G    GS        MPG  \
# 0      1975.0       Zaid Abdul-Aziz    C  28.0  HOU  65.0   NaN  22.307692
# 1      1975.0  Kareem Abdul-Jabbar*    C  27.0  MIL  65.0   NaN  42.261538
# 2      1975.0             Don Adams   SF  27.0  DET  51.0   NaN  26.980392
# 3      1975.0          Rick Adelman   PG  28.0  TOT  58.0   NaN  18.517241
# 4      1975.0          Lucius Allen   PG  27.0  TOT  66.0   NaN  35.651515
# ...       ...                   ...  ...   ...  ...   ...   ...        ...
# 14423  2017.0          Tyler Zeller    C  27.0  BOS  51.0   5.0  10.294118
# 14424  2017.0           Paul Zipser   SF  22.0  CHI  44.0  18.0  19.159091
# 14425  2017.0           Ivica Zubac    C  19.0  LAL  38.0  11.0  16.026316
# 14426     NaN                   NaN  NaN   NaN  NaN   NaN   NaN        NaN
# 14427     NaN                   NaN  NaN   NaN  NaN   NaN   NaN        NaN
#
# ...

# %%
df1 = df1.fillna('')
df1
# Out:
#          Year                Player Pos   Age   Tm     G    GS        MPG  \
# 0      1975.0       Zaid Abdul-Aziz   C  28.0  HOU  65.0        22.307692
# 1      1975.0  Kareem Abdul-Jabbar*   C  27.0  MIL  65.0        42.261538
# 2      1975.0             Don Adams  SF  27.0  DET  51.0        26.980392
# 3      1975.0          Rick Adelman  PG  28.0  TOT  58.0        18.517241
# 4      1975.0          Lucius Allen  PG  27.0  TOT  66.0        35.651515
# ...       ...                   ...  ..   ...  ...   ...   ...        ...
# 14423  2017.0          Tyler Zeller   C  27.0  BOS  51.0   5.0  10.294118
# 14424  2017.0           Paul Zipser  SF  22.0  CHI  44.0  18.0  19.159091
# 14425  2017.0           Ivica Zubac   C  19.0  LAL  38.0  11.0  16.026316
# 14426
# 14427
#
#            MP PER/Dis  ...   STL/Dis    STL   BLK/Dis    BLK       TPG   TOV  \
# 0      1450.0    17.1  ...  0.569231   37.0  1.138462   74.0       0.0
# ...

# %%
df1 = df1.set_index('Year')
df1
# Out:
#                     Player Pos  Age   Tm   G    GS        MPG    MP  PER/Dis  \
# Year
# 1975       Zaid Abdul-Aziz   C   28  HOU  65        22.307692  1450     17.1
# 1975  Kareem Abdul-Jabbar*   C   27  MIL  65        42.261538  2747     26.4
# 1975             Don Adams  SF   27  DET  51        26.980392  1376      8.4
# 1975          Rick Adelman  PG   28  TOT  58        18.517241  1074     11.1
# 1975          Lucius Allen  PG   27  TOT  66        35.651515  2353     17.5
# ...                    ...  ..  ...  ...  ..   ...        ...   ...      ...
# 2017            Randy Foye  SG   33  BRK  69  40.0  18.608696  1284      7.3
# 2017           Tim Frazier  PG   26  NOP  65  35.0  23.461538  1525     12.4
# 2017         Channing Frye   C   33  CLE  74  15.0  18.891892  1398     15.6
# 2017      Danilo Gallinari  SF   28  DEN  63  63.0  33.873016  2134     17.4
# 2017     Langston Galloway  PG   25  TOT  74   2.0  20.202703  1495     10.4
#
# ...

# %%
df1 = df1.sort_values(by = 'Year', ascending = True).head(25000)
df1
# Out:
#                Player Pos  Age   Tm   G    GS        MPG    MP  PER/Dis   PER  \
# Year
# 1975  Zaid Abdul-Aziz   C   28  HOU  65        22.307692  1450     17.1  17.1
# 1975         Bob Love  PF   32  CHI  61        39.360656  2401     15.0  15.0
# 1975      Tom Kozelko  PF   23  WSB  73        10.328767   754      6.7   6.7
# 1975     Bob Kauffman  PF   28  ATL  73        10.917808   797     12.6  12.6
# 1975   Mickey Johnson  PF   22  CHI  38         7.657895   291     17.6  17.6
# ...               ...  ..  ...  ...  ..   ...        ...   ...      ...   ...
# 2017    Nicolas Batum  SG   28  CHO  77  77.0  33.987013  2617     15.8  15.8
# 2017      Bryn Forbes  SG   23  SAS  36   0.0   7.916667   285      5.9   5.9
# 2017    Evan Fournier  SG   24  ORL  68  66.0  32.852941  2234     13.9  13.9
# 2017      Mike Conley  PG   29  MEM  69  68.0  33.217391  2292     23.2  23.2
# 2017        Ron Baker  SG   23  NYK  52  13.0  16.480769   857      7.5   7.5
#
# ...

# %%
df1 = df1[df1['G'] >= 25]
df1
# Out:
#                  Player Pos  Age   Tm   G    GS        MPG    MP  PER/Dis  \
# Year
# 1975    Zaid Abdul-Aziz   C   28  HOU  65   NaN  22.307692  1450     17.1
# 1975       Louie Nelson  PG   23  NOJ  72   NaN  26.361111  1898     12.8
# 1975        Mike Newlin  SG   26  HOU  79   NaN  34.291139  2709     15.1
# 1975          Jim Owens  SF   24  PHO  41   NaN  10.536585   432      9.3
# 1975    Steve Patterson   C   26  CLE  81   NaN  15.666667  1269     11.3
# ...                 ...  ..  ...  ...  ..   ...        ...   ...      ...
# 2017    Michael Beasley  PF   28  MIL  56   6.0  16.696429   935     17.8
# 2017       Bradley Beal  SG   23  WAS  77  77.0  34.857143  2684     20.1
# 2017      Kent Bazemore  SF   27  ATL  73  64.0  26.890411  1963     11.5
# 2017      Nicolas Batum  SG   28  CHO  77  77.0  33.987013  2617     15.8
# 2017  Langston Galloway  PG   25  TOT  74   2.0  20.202703  1495     10.4
#
# ...

# %%
guards = ['PG','SG']

df1[df1['Pos'].isin(guards)]
# Out:
#               Player Pos  Age   Tm   G    GS        MPG    MP  PER/Dis   PER  \
# Year
# 1975           Jo Jo  PG   28  BOS  82        39.268293  3220     14.9  14.9
# 1975    Lee Winfield  PG   27  BUF  68        18.514706  1259     11.8  11.8
# 1975    Ron Williams  PG   30  MIL  46        11.434783   526      9.2   9.2
# 1975  Lenny Wilkens*  PG   37  POR  65        17.861538  1161     16.6  16.6
# 1975       Bob Weiss  PG   32  BUF  76        17.605263  1338     10.5  10.5
# ...              ...  ..  ...  ...  ..   ...        ...   ...      ...   ...
# 2017   Nicolas Batum  SG   28  CHO  77  77.0  33.987013  2617     15.8  15.8
# 2017     Bryn Forbes  SG   23  SAS  36   0.0   7.916667   285      5.9   5.9
# 2017   Evan Fournier  SG   24  ORL  68  66.0  32.852941  2234     13.9  13.9
# 2017     Mike Conley  PG   29  MEM  69  68.0  33.217391  2292     23.2  23.2
# 2017       Ron Baker  SG   23  NYK  52  13.0  16.480769   857      7.5   7.5
#
# ...

# %%
forwards = ['SF', 'PF']

df1[df1['Pos'].isin(forwards)]
# Out:
#                Player Pos  Age   Tm   G    GS        MPG    MP  PER/Dis   PER  \
# Year
# 1975         Bob Love  PF   32  CHI  61        39.360656  2401     15.0  15.0
# 1975      Tom Kozelko  PF   23  WSB  73        10.328767   754      6.7   6.7
# 1975     Bob Kauffman  PF   28  ATL  73        10.917808   797     12.6  12.6
# 1975   Mickey Johnson  PF   22  CHI  38         7.657895   291     17.6  17.6
# 1975    Kevin Restani  PF   23  MIL  76        23.092105  1755      9.7   9.7
# ...               ...  ..  ...  ...  ..   ...        ...   ...      ...   ...
# 2017         Ed Davis  PF   27  POR  46  12.0  17.152174   789     11.5  11.5
# 2017       Boris Diaw  PF   34  UTA  73  33.0  17.575342  1283      9.0   9.0
# 2017     Gorgui Dieng  PF   27  MIN  82  82.0  32.353659  2653     14.2  14.2
# 2017     Jared Dudley  PF   31  PHO  64   7.0  21.281250  1362     10.6  10.6
# 2017  Marquese Chriss  PF   19  PHO  82  75.0  21.256098  1743     12.3  12.3
#
# ...

# %%
center = ['C']

df1[df1['Pos'].isin(center)]
# Out:
#                    Player Pos  Age   Tm   G    GS        MPG    MP  PER/Dis  \
# Year
# 1975      Zaid Abdul-Aziz   C   28  HOU  65        22.307692  1450     17.1
# 1975           Luke Witte   C   24  CLE  39         6.948718   271     12.5
# 1975       Mike Sojourner   C   21  ATL  73        29.164384  2129     14.1
# 1975       Nate Thurmond*   C   33  CHI  80        34.450000  2756     13.4
# 1975          Wes Unseld*   C   28  WSB  73        39.780822  2904     15.0
# ...                   ...  ..  ...  ...  ..   ...        ...   ...      ...
# 2017        Anthony Davis   C   23  NOP  75  75.0  36.106667  2708     27.5
# 2017         Steven Adams   C   23  OKC  80  80.0  29.862500  2389     16.5
# 2017        Alexis Ajinca   C   28  NOP  39  15.0  14.974359   584     12.9
# 2017  Willie Cauley-Stein   C   23  SAC  75  21.0  18.946667  1421     16.4
# 2017       Andre Drummond   C   23  DET  81  81.0  29.740741  2409     20.9
#
# ...

# %%
df1 = df1.filter(items = ['Player','Age','PPG', 'ASG', 'RBG','STL/Dis','BLK/Dis','FG/Dis','3Pper','2p/Dis','FT/Dis','Pos'])
df1
# Out:
#                      Player   Age        PPG       ASG        RBG   STL/Dis  \
# 0           Zaid Abdul-Aziz  28.0   9.676923  1.292308   7.507692  0.569231
# 1      Kareem Abdul-Jabbar*  27.0  29.984615  4.061538  14.030769         1
# 2                 Don Adams  27.0   5.862745  1.470588   4.784314  1.352941
# 3              Rick Adelman  28.0   5.500000  1.931034   1.637931  1.206897
# 4              Lucius Allen  27.0  19.090909  5.636364   4.212121  2.060606
# ...                     ...   ...        ...       ...        ...       ...
# 14423          Tyler Zeller  27.0   3.490196  0.823529   2.431373  0.137255
# 14424           Paul Zipser  22.0   5.454545  0.818182   2.840909  0.340909
# 14425           Ivica Zubac  19.0   7.473684  0.789474   4.184211  0.368421
# 14426                   NaN   NaN        NaN       NaN
# 14427                   NaN   NaN        NaN       NaN                  NaN
#
#         BLK/Dis    FG/Dis     3Pper    2p/Dis    FT/Dis  Pos
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14428 entries, 0 to 14427
# Data columns (total 48 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          13489 non-null  float64
#  1   Player        13489 non-null  object
#  2   Pos           13489 non-null  object
#  3   Age           13489 non-null  float64
#  4   Tm            13489 non-null  object
#  5   G             13489 non-null  float64
#  6   GS            11876 non-null  float64
#  7   MPG           13489 non-null  float64
#  8   MP            13489 non-null  float64
#  9   PER/Dis       13490 non-null  object
#  10  PER           13489 non-null  float64
#  11  TS/Dis        13489 non-null  float64
#  12  TS%           13489 non-null  float64
#  13  USG/Dis       13489 non-null  float64
#  14  USG%          12824 non-null  float64
#  15  WS/Dis        13489 non-null  float64
#  16  WS            13489 non-null  float64
# ...

# %%
df1_1 = df1.copy()
#df1_1['FG/Dis']= df1_1['FG/Dis'].astype(int)

# %%
#df1_1['FG/Dis'] = pd.to_numeric(df1_1['FG/Dis'])

# %%
#d1 = lambda x:float(x[1:-1])

# %%
#df1.TOV= df1.TOV.apply(d1)

# %%
#df1 = df1.fillna('')
#df1

# %%
#x = np.random.normal(50, 3, 1000)
#source = {"Pos": ["PG"]*1000, "PTS": x}
#df1 = pd.DataFrame(source)

# Calculating mean and Stdev of PTS
#df1_mean = np.mean(df1["PTS"])
#df1_std = np.std(df1["PTS"])
 
# Calculating probability density function (PDF)
#pdf = stats.norm.pdf(df1["PTS"].sort_values(), df1_mean, df1_std)

# Drawing a graph
#plt.plot(df1["PTS"].sort_values(), pdf)
#plt.xlim([40,60])  
#plt.xlabel("PPS", size=12)    
#plt.ylabel("Frequency", size=12)                
#plt.grid(True, alpha=0.3, linestyle="--")
#plt.show()

# %%
df1.to_excel('seasons(updated).xlsx', sheet_name = 'Data')

# %%
with pd.ExcelWriter('seasons(updated).xlsx') as writer:
    df1.to_excel(writer, sheet_name = 'Data')

# %%
sns.distplot(df1['3Pper'], bins=25)
# Out:
# C:\Users\sbrooks003\AppData\Local\Temp\ipykernel_12560\252697939.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['3Pper'], bins=25)
# <Axes: xlabel='3Pper', ylabel='Density'>

# %%
plt.figure(figsize=(6,4))
fig = sns.distplot(df1['3Pper'], color ='Blue')
fig.set_xlabel("3P Percentage for All Positions", size=15)
fig.set_ylabel("Density of Percentages", size=15)
plt.title("Distribution for 3P Percentage", size=30)
plt.show()
# Out:
# C:\Users\sbrooks003\AppData\Local\Temp\ipykernel_12560\2898709420.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   fig = sns.distplot(df1['3Pper'], color ='Blue')

# %%
sns.distplot(df1['FT/Dis'], bins=25)
# Out:
# C:\Users\sbrooks003\AppData\Local\Temp\ipykernel_4812\850318204.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['FT/Dis'], bins=25)
# <Axes: xlabel='FT/Dis', ylabel='Density'>

# %%
plt.figure(figsize=(6,4))
fig = sns.distplot(df1['FT/Dis'], color ='Blue')
fig.set_xlabel("FT Percentage for All Positions", size=15)
fig.set_ylabel("Density of Percentages", size=15)
plt.title("Distribution for FT Percentage", size=30)
plt.show()
# Out:
# C:\Users\sbrooks003\AppData\Local\Temp\ipykernel_12560\99562985.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   fig = sns.distplot(df1['FT/Dis'], color ='Blue')

# %%
sns.distplot(df1['FG/Dis'], bins=25)
# Out:
# C:\Users\sbrooks003\AppData\Local\Temp\ipykernel_4812\1828129257.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['FG/Dis'], bins=25)
# <Axes: xlabel='FG/Dis', ylabel='Density'>

# %%
#plt.figure(figsize=(6,4))
#fig = sns.distplot(df1['FG/Dis'], color ='Blue')
#fig.set_xlabel("FG Percentage for All Positions", size=15)
#fig.set_ylabel("Density of Percentages", size=15)
#plt.title("Distribution for FG Percentage", size=30)
#plt.show()

# %%
sns.distplot(df1['2p/Dis'], bins=25)
# Out:
# C:\Users\sbrooks003\AppData\Local\Temp\ipykernel_4812\12801311.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['2p/Dis'], bins=25)
# <Axes: xlabel='2p/Dis', ylabel='Density'>

# %%
df1.head()

# %%
sns.jointplot(x='3Pper',y='Pos',data=df1)

# %%
sns.jointplot(x='FG/Dis',y='Pos',data=df1)

# %%
sns.jointplot(x='FT/Dis',y='Pos',data=df1)

# %%
sns.jointplot(x='2p/Dis',y='Pos',data=df1)

# %%
sns.pairplot(df1, hue ='Pos')

# %%
#plt.figure(figsize=(10,7))
#fig = sns.distplot(df1['3Pper'], color ='Blue')
#fig.set_xlabel("3P Percentage for all positions", size=15)
#fig.set_ylabel("Density of Percentages", size=15)
#plt.title("Distribution for 3P Percentage", size=30)
#plt.show()
